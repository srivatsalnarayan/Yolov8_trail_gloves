# %% [markdown]
# <a href="https://colab.research.google.com/github/srivatsalnarayan/Yolov8_trail_gloves/blob/main/yolov8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Wed Sep 27 10:43:14 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P8    10W /  70W |      3MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content/drive/MyDrive/Colab Notebooks/yolov

# %%
# !pip install ultralytics==8.0.20

# %%
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.3/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !ls
# Out:
# data  data.yaml  yolov8.ipynb

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/yolov
# Out:
# /content/drive/MyDrive/Colab Notebooks/yolov

# %%
# !ls
# Out:
# data  data.yaml  yolov8.ipynb

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=data.yaml epochs=25 imgsz=224 plots=True
# Out:
# ...
# 100% 21.5M/21.5M [00:00<00:00, 171MB/s]
#
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !ls runs/detect/train/
# Out:
# args.yaml					    train_batch0.jpg
# confusion_matrix.png				    train_batch120.jpg
# events.out.tfevents.1695811500.d2021a2b4e0d.3685.0  train_batch121.jpg
# F1_curve.png					    train_batch122.jpg
# P_curve.png					    train_batch1.jpg
# PR_curve.png					    train_batch2.jpg
# R_curve.png					    val_batch0_labels.jpg
# results.csv					    val_batch0_pred.jpg
# results.png					    weights

# %%
Image(filename='/content/drive/MyDrive/Colab Notebooks/yolov/runs/detect/train/confusion_matrix.png', width=600)

# %%
Image(filename='/content/drive/MyDrive/Colab Notebooks/yolov/runs/detect/train/results.png', width=600)

# %%
Image(filename='/content/drive/MyDrive/Colab Notebooks/yolov/runs/detect/train/train_batch121.jpg', width=600)

# %%
# !yolo task=detect mode=val model='runs/detect/train/weights/best.pt' data=data.yaml
# Out:
# 2023-09-27 10:54:46.673762: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-27 10:54:47.736710: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11127519 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/drive/MyDrive/Colab Notebooks/yolov/data/valid/labels.cache... 31 images, 0 backgrounds, 0 corrupt: 100% 31/31 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.29it/s]
#                    all         31        101      0.899      0.803      0.867      0.501
# ...

# %%
# !yolo task=detect mode=predict model=runs/detect/train/weights/best.pt conf=0.25 source=data/test/images
# Out:
# 2023-09-27 10:57:48.945114: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-27 10:57:50.102464: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11127519 parameters, 0 gradients, 28.4 GFLOPs
# image 1/31 /content/drive/MyDrive/Colab Notebooks/yolov/data/test/images/1.jpeg: 192x224 1 Helmet, 1 Goggles, 2 Glovess, 67.1ms
# image 2/31 /content/drive/MyDrive/Colab Notebooks/yolov/data/test/images/10.jpeg: 160x224 3 Glovess, 63.9ms
# image 3/31 /content/drive/MyDrive/Colab Notebooks/yolov/data/test/images/11.jpeg: 224x224 3 Glovess, 7.9ms
# ...
